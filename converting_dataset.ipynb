# %% [markdown]
# <a href="https://colab.research.google.com/github/jcjang1/kaggle_dataset_maker/blob/main/converting_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rasterio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.3 MB 1.2 MB/s
# ...

# %%
# !gdown 12OOWUZKFm_dX0J-p9NASyUv2GIcYK4Nx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=12OOWUZKFm_dX0J-p9NASyUv2GIcYK4Nx
# To: /content/original_dataset_images.zip
# 100% 6.14G/6.14G [00:55<00:00, 110MB/s]

# %%
# !mkdir origin_dataset

# %%
# !unzip /content/original_dataset_images.zip -d /content/origin_dataset
# Out:
# Archive:  /content/original_dataset_images.zip
#    creating: /content/origin_dataset/train_images/
#   inflating: /content/origin_dataset/train_images/10044.tiff
#   inflating: /content/origin_dataset/train_images/10274.tiff
#   inflating: /content/origin_dataset/train_images/10392.tiff
#   inflating: /content/origin_dataset/train_images/10488.tiff
#   inflating: /content/origin_dataset/train_images/10610.tiff
#   inflating: /content/origin_dataset/train_images/10611.tiff
#   inflating: /content/origin_dataset/train_images/10651.tiff
#   inflating: /content/origin_dataset/train_images/10666.tiff
#   inflating: /content/origin_dataset/train_images/10703.tiff
#   inflating: /content/origin_dataset/train_images/10892.tiff
#   inflating: /content/origin_dataset/train_images/10912.tiff
#   inflating: /content/origin_dataset/train_images/10971.tiff
#   inflating: /content/origin_dataset/train_images/10992.tiff
#   inflating: /content/origin_dataset/train_images/11064.tiff
# ...

# %%
import gc # 할당된 메모리 관리 // https://blog.winterjung.dev/2018/02/18/python-gc
import os 
import cv2
import zipfile
import rasterio # 데이터 분석 // https://programmerpsy.tistory.com/106
import numpy as np
import pandas as pd
from PIL import Image
import tifffile as tiff
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from rasterio.windows import Window
from torch.utils.data import Dataset

# %%
OUT_TRAIN = 'train.zip'
OUT_MASKS = 'masks.zip'
sz = 3072   # the size of tiles
reduce = 1 # reduce the original images by 4 times 
MASKS = '/content/train.csv'
DATA = '/content/origin_dataset/train_images'

# %%
# train csv
# !gdown 1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CYzwew45Tuzs1w0oNbraDT4F8RoMlq1O
# To: /content/train.csv
# 100% 16.4M/16.4M [00:00<00:00, 258MB/s]

# %%
# functions to convert encoding to mask and mask to encoding
def enc2mask(encs, shape):
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for m,enc in enumerate(encs):
        if isinstance(enc,np.float) and np.isnan(enc): continue
        s = enc.split()
        for i in range(len(s)//2):
            start = int(s[2*i]) - 1
            length = int(s[2*i+1])
            img[start:start+length] = 1 + m
    return img.reshape(shape).T

def mask2enc(mask, n=1):
    pixels = mask.T.flatten()
    encs = []
    for i in range(1,n+1):
        p = (pixels == i).astype(np.int8)
        if p.sum() == 0: encs.append(np.nan)
        else:
            p = np.concatenate([[0], p, [0]])
            runs = np.where(p[1:] != p[:-1])[0] + 1
            runs[1::2] -= runs[::2]
            encs.append(' '.join(str(x) for x in runs))
    return encs

df_masks = pd.read_csv(MASKS)[['id', 'rle']].set_index('id')
df_masks.head()
# Out:
#                                                      rle
# id
# 10044  1459676 77 1462675 82 1465674 87 1468673 92 14...
# 10274  715707 2 718705 8 721703 11 724701 18 727692 3...
# 10392  1228631 20 1231629 24 1234624 40 1237623 47 12...
# 10488  3446519 15 3449517 17 3452514 20 3455510 24 34...
# 10610  478925 68 481909 87 484893 105 487863 154 4908...

# %%
# one of the new images cannot be loaded into 16GB RAM
# use rasterio to load image part by part
# using a dataset similar to my submission kernel

s_th = 40  # saturation blancking threshold
p_th = 1000*(sz // 3072) ** 2 # threshold for the minimum number of pixels


class HuBMAPDataset(Dataset):
    def __init__(self, idx, sz=sz, reduce=reduce, encs=None):
        self.data = rasterio.open(os.path.join(DATA,str(idx)+'.tiff'),num_threads='all_cpus')
        # some images have issues with their format 
        # and must be saved correctly before reading with rasterio
        if self.data.count != 3:
            subdatasets = self.data.subdatasets
            self.layers = []
            if len(subdatasets) > 0:
                for i, subdataset in enumerate(subdatasets, 0):
                    self.layers.append(rasterio.open(subdataset))
        self.shape = self.data.shape
        self.reduce = reduce
        self.sz = reduce*sz
        self.pad0 = (self.sz - self.shape[0]%self.sz)%self.sz
        self.pad1 = (self.sz - self.shape[1]%self.sz)%self.sz
        self.n0max = (self.shape[0] + self.pad0)//self.sz
        self.n1max = (self.shape[1] + self.pad1)//self.sz
        self.mask = enc2mask(encs,(self.shape[1],self.shape[0])) if encs is not None else None
        
    def __len__(self):
        return self.n0max*self.n1max
    
    def __getitem__(self, idx):
        # the code below may be a little bit difficult to understand,
        # but the thing it does is mapping the original image to
        # tiles created with adding padding (like in the previous version of the kernel)
        # then the tiles are loaded with rasterio
        # n0,n1 - are the x and y index of the tile (idx = n0*self.n1max + n1)
        n0,n1 = idx//self.n1max, idx%self.n1max
        # x0,y0 - are the coordinates of the lower left corner of the tile in the image
        # negative numbers correspond to padding (which must not be loaded)
        x0,y0 = -self.pad0//2 + n0*self.sz, -self.pad1//2 + n1*self.sz

        # make sure that the region to read is within the image
        p00,p01 = max(0,x0), min(x0+self.sz,self.shape[0])
        p10,p11 = max(0,y0), min(y0+self.sz,self.shape[1])
        img = np.zeros((self.sz,self.sz,3),np.uint8)
        mask = np.zeros((self.sz,self.sz),np.uint8)
        # mapping the loade region to the tile
        if self.data.count == 3:
            img[(p00-x0):(p01-x0),(p10-y0):(p11-y0)] = np.moveaxis(self.data.read([1,2,3],
                window=Window.from_slices((p00,p01),(p10,p11))), 0, -1)
        else:
            for i,layer in enumerate(self.layers):
                img[(p00-x0):(p01-x0),(p10-y0):(p11-y0),i] =\
                  layer.read(1,window=Window.from_slices((p00,p01),(p10,p11)))
        if self.mask is not None: mask[(p00-x0):(p01-x0),(p10-y0):(p11-y0)] = self.mask[p00:p01,p10:p11]
        
        if self.reduce != 1:
            img = cv2.resize(img,(self.sz//reduce,self.sz//reduce),
                             interpolation = cv2.INTER_AREA)
            mask = cv2.resize(mask,(self.sz//reduce,self.sz//reduce),
                             interpolation = cv2.INTER_NEAREST)
        #check for empty imges
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        h,s,v = cv2.split(hsv)
        #return -1 for empty images
        return img, mask, (-1 if (s>s_th).sum() <= p_th or img.sum() <= p_th else idx)

# %%
x_tot,x2_tot = [],[]
with zipfile.ZipFile(OUT_TRAIN, 'w') as img_out,\
 zipfile.ZipFile(OUT_MASKS, 'w') as mask_out:
    for index, encs in tqdm(df_masks.iterrows(),total=len(df_masks)):
        #image+mask dataset
        ds = HuBMAPDataset(index,encs=encs)
        for i in range(len(ds)):
            im,m,idx = ds[i]
            if idx < 0: continue
                
            x_tot.append((im/255.0).reshape(-1,3).mean(0))
            x2_tot.append(((im/255.0)**2).reshape(-1,3).mean(0))
            
            #write data   
            im = cv2.imencode('.png',cv2.cvtColor(im, cv2.COLOR_RGB2BGR))[1]
            img_out.writestr(f'{index}_{idx:04d}.png', im)
            m = cv2.imencode('.png',m)[1]
            mask_out.writestr(f'{index}_{idx:04d}.png', m)
        
#image stats
img_avr =  np.array(x_tot).mean(0)
img_std =  np.sqrt(np.array(x2_tot).mean(0) - img_avr**2)
print('mean:',img_avr, ', std:', img_std)
# Out:
#   0%|          | 0/351 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """
# mean: [0.7800886  0.7561629  0.77305207] , std: [0.2553396  0.26838737 0.26364971]

# %%
len(x_tot)
# Out:
# 351

# %%
columns, rows = 4,4
idx0 = 20
fig=plt.figure(figsize=(columns*4, rows*4))
with zipfile.ZipFile(OUT_TRAIN, 'r') as img_arch, \
     zipfile.ZipFile(OUT_MASKS, 'r') as msk_arch:
    fnames = sorted(img_arch.namelist())[8:]
    for i in range(rows):
        for j in range(columns):
            idx = i+j*columns
            img = cv2.imdecode(np.frombuffer(img_arch.read(fnames[idx0+idx]), 
                                             np.uint8), cv2.IMREAD_COLOR)
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            mask = cv2.imdecode(np.frombuffer(msk_arch.read(fnames[idx0+idx]), 
                                              np.uint8), cv2.IMREAD_GRAYSCALE)
    
            fig.add_subplot(rows, columns, idx+1)
            plt.axis('off')
            plt.imshow(Image.fromarray(img))
            plt.imshow(Image.fromarray(mask), alpha=0.2)
plt.show()

# %%
# !mkdir /content/original_dataset
# !mkdir /content/original_dataset/images
# !mkdir /content/original_dataset/masks

# %%
# !unzip /content/train.zip -d /content/original_dataset/images
# !unzip /content/masks.zip -d /content/original_dataset/masks
# Out:
# Archive:  /content/train.zip
#  extracting: /content/original_dataset/images/10044_0000.png
#  extracting: /content/original_dataset/images/10274_0000.png
#  extracting: /content/original_dataset/images/10392_0000.png
#  extracting: /content/original_dataset/images/10488_0000.png
#  extracting: /content/original_dataset/images/10610_0000.png
#  extracting: /content/original_dataset/images/10611_0000.png
#  extracting: /content/original_dataset/images/10651_0000.png
#  extracting: /content/original_dataset/images/10666_0000.png
#  extracting: /content/original_dataset/images/10703_0000.png
#  extracting: /content/original_dataset/images/10892_0000.png
#  extracting: /content/original_dataset/images/10912_0000.png
#  extracting: /content/original_dataset/images/10971_0000.png
#  extracting: /content/original_dataset/images/10992_0000.png
#  extracting: /content/original_dataset/images/11064_0000.png
#  extracting: /content/original_dataset/images/1123_0000.png
# ...

# %%
# !zip original_dataset.zip -r ./original_dataset
# Out:
#   adding: original_dataset/ (stored 0%)
#   adding: original_dataset/masks/ (stored 0%)
#   adding: original_dataset/masks/29424_0000.png (deflated 18%)
#   adding: original_dataset/masks/2696_0000.png (deflated 18%)
#   adding: original_dataset/masks/19084_0000.png (deflated 26%)
#   adding: original_dataset/masks/7169_0000.png (deflated 46%)
#   adding: original_dataset/masks/23243_0000.png (deflated 57%)
#   adding: original_dataset/masks/15860_0000.png (deflated 84%)
#   adding: original_dataset/masks/22016_0000.png (deflated 24%)
#   adding: original_dataset/masks/12466_0000.png (deflated 36%)
#   adding: original_dataset/masks/7569_0000.png (deflated 74%)
#   adding: original_dataset/masks/29238_0000.png (deflated 87%)
#   adding: original_dataset/masks/6120_0000.png (deflated 16%)
#   adding: original_dataset/masks/28052_0000.png (deflated 93%)
#   adding: original_dataset/masks/27298_0000.png (deflated 60%)
#   adding: original_dataset/masks/1731_0000.png (deflated 75%)
# ...

# %%
# !mv /content/original_dataset.zip /content/drive/MyDrive/data/kaggle/original_dataset.zip

# %%
img_path = '/content/original_dataset/images/'
mask_path = '/content/original_dataset/masks/'

aa = os.listdir(img_path)
bb = os.listdir(mask_path)

# %%
import matplotlib.pyplot as plt

img = cv2.imread(img_path + aa[0])
img = np.array(img)

img_up = img[:1536, :, :]
img_down = img[1536:, :, :]
img_left = img[:, :1536, :]
img_right = img[:, 1536:, :]

# %%
test_concat1 = np.concatenate((img_up, img_down), axis=0)
test_concat2 = np.concatenate((img_left, img_right), axis=1)

# %%
plt.imshow(test_concat1)
plt.show()
print(test_concat1.shape)
plt.imshow(test_concat2)
plt.show()
print(test_concat2.shape)
# Out:
# (3072, 3072, 3)
# (3072, 3072, 3)

# %%
plt.imshow(img_up)
plt.show()
plt.imshow(img_down)
plt.show()
plt.imshow(img_left)
plt.show()
plt.imshow(img_right)
plt.show()

# %%
for a in aa:
    img = cv2.imread(img_path + a)
    mask = cv2.imread(mask_path + a)

    print(img.shape, mask.shape)

# %%
import os 

test_a = os.listdir('/content/conv_768_r2_dataset/masks/')
len(test_a)
# Out:
# 1404

# %%
def class_counter(path):
    classes = ['background', 'kidney', 'prostate', 'largeintestine', 'spleen', 'lung']

    counter = {
        'background' : 0,
        'kidney' : 0,
        'prostate' : 0,
        'largeintestine' : 0,
        'spleen' : 0,
        'lung' : 0,
        'total' : 0
    }

    file_name = os.listdir(path)

    for names in file_name:

        mask_img = cv2.imread(path + f'/{names}')
        class_name = classes[mask_img.max()]

        counter[class_name] += 1
        counter['total'] += 1
        
    return counter

# %%
class_counter('/content/conv_768_r2_dataset/masks')
# Out:
# {'background': 251,
#  'kidney': 1153,
#  'prostate': 0,
#  'largeintestine': 0,
#  'spleen': 0,
#  'lung': 0,
#  'total': 1404}

# %%
# Out:
# (768, 768, 3)
